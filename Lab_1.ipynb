# %% [markdown]
# <a href="https://colab.research.google.com/github/Harivamsh2005/Python-For-data-Science/blob/main/Lab_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Factorial of a Number Using Recursion

# %%
def factorial(n):

    # Base Case
    if n == 0 or n == 1:
        return 1

    # Recursive Case
    else:
        return n * factorial(n - 1)


num = int(input("Enter a number: "))

# Check for negative numbers
if num < 0:
    print("Factorial is not defined for negative numbers.")
else:
    result = factorial(num)
    print(f"Factorial of {num} = {result}")
# Out:
# Enter a number: 5
# Factorial of 5 = 120

# %% [markdown]
# Recursive Function to Calculate the Sum of Digits

# %%
def sum_of_digits(n):

    # Base Case
    if n == 0:
        return 0

    # Recursive Case
    return (n % 10) + sum_of_digits(n // 10)


# Accept user input
number = int(input("Enter a positive integer: "))

# Handle negative numbers
if number < 0:
    print("Please enter a positive integer.")
else:
    result = sum_of_digits(number)
    print("Sum of digits =", result)
# Out:
# Enter a positive integer: 12345
# Sum of digits = 15

# %% [markdown]
#  Python Program to Reverse a String Using Recursion

# %%
# Python Program to Reverse a String Using Recursion

def reverse_string(text):

    # Base Case
    if len(text) == 0:
        return text

    # Recursive Case
    return reverse_string(text[1:]) + text[0]


# Accept user input
string = input("Enter a string: ")

# Display the reversed string
print("Reversed String =", reverse_string(string))
# Out:
# Enter a string: Ravi
# Reversed String = ivaR

# %% [markdown]
# Count the Number of Digits Using Recursion

# %%
def count_digits(n):

    # Base Case
    if n < 10:
        return 1

    # Recursive Case
    return 1 + count_digits(n // 10)


# Accept user input
number = int(input("Enter an integer: "))

# Handle negative numbers
number = abs(number)

# Display the result
print("Number of Digits =", count_digits(number))
# Out:
# Enter an integer: 12345
# Number of Digits = 5
